# %% [markdown]
# ## Here I just visualize some graphs

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## plot of ELM example

# %%
df_30 = pd.read_csv(f'/compass/Shared/Users/bogdanov/vyzkumny_ukol/data/mirnov_coil_signal_30kHz/shot_18463.csv')
df_300= pd.read_csv(f'/compass/Shared/Users/bogdanov/vyzkumny_ukol/data/mirnov_coil_signal_300kHz/shot_18463.csv')
df_150 = pd.read_csv(f'/compass/Shared/Users/bogdanov/vyzkumny_ukol/data/mirnov_coil_signal_150kHz/shot_18463.csv')


fig, ax = plt.subplots(3, 1, figsize=(10, 8))
ax[0].set_title(f'ELM shot 18463, time 1128.38 ms')
ax[0].plot(np.arange(160*(-0.0035), 160*0.0035, 0.0035), df_300.iloc[47687-2-160:47687-2+160]['mcDIV'].values, label=f'300 kHz')
ax[0].vlines(0, -45, 45, color='black', alpha=0.5)
ax[0].vlines(-0.054, -45, 45, color='r', label='start ELM')
ax[0].vlines(0.349, -45, 45, color='r', label='end ELM')
ax[0].legend()

ax[1].plot(np.arange(160*(-0.0065), 160*0.0065, 0.0065), df_150.iloc[25678-2-160:25678-2+160]['mcDIV'].values, label=f'150 kHz')
ax[1].vlines(0, -45, 45, color='black', alpha=0.5)
ax[1].vlines(-0.054, -45, 45, color='r')
ax[1].vlines(0.349, -45, 45, color='r')
ax[1].set_ylabel('Normalized signal from Mirnov coil ')
ax[1].legend()

ax[2].plot(np.arange(160*(-0.0335), 160*0.0335, 0.0335), df_30.iloc[4983-2-160:4983-2+160]['mcDIV'].values, label=f'30 kHz')
ax[2].vlines(0, -45, 45, color='black', alpha=0.5)
ax[2].vlines(-0.054, -45, 45, color='r')
ax[2].vlines(0.349, -45, 45, color='r')
ax[2].set_xlabel('Time [ms]')
ax[2].legend()

# %% [markdown]
# ## Plot of H-mode example

# %%
fig, ax = plt.subplots(3, 1, figsize=(10, 8))
ax[0].set_title(f'H-mode shot 18463, time 1104.4 ms')
ax[0].plot(np.arange(160*(-0.0035), 160*0.0035, 0.0035), df_300.iloc[40848-2-160:40848-2+160]['mcDIV'].values, label=f'300 kHz')
ax[0].vlines(0, -10, 10, color='black', alpha=0.5)
ax[0].legend()

ax[1].plot(np.arange(160*(-0.0065), 160*0.0065, 0.0065), df_150.iloc[21995-2-160:21995-2+160]['mcDIV'].values, label=f'150 kHz')
ax[1].vlines(0, -10, 10, color='black', alpha=0.5)
ax[1].set_ylabel('Normalized signal from Mirnov coil ')
ax[1].legend()

ax[2].plot(np.arange(160*(-0.0335), 160*0.0335, 0.0335), df_30.iloc[4269-2-160:4269-2+160]['mcDIV'].values, label=f'30 kHz')
ax[2].vlines(0, -10, 10, color='black', alpha=0.5)
ax[2].set_xlabel('Time [ms]')
ax[2].legend()

# %% [markdown]
# # Plot of L-mode example

# %%
fig, ax = plt.subplots(3, 1, figsize=(10, 8))
ax[0].set_title(f'L-mode shot 18463, time 1015 ms')
ax[0].plot(np.arange(160*(-0.0035), 160*0.0035, 0.0035), df_300.iloc[15000:15000+160+160]['mcDIV'].values, label=f'300 kHz')
ax[0].vlines(0, -10, 10, color='black', alpha=0.5)
ax[0].legend()

ax[1].plot(np.arange(160*(-0.0065), 160*0.0065, 0.0065), df_150.iloc[7500:7500+160+160]['mcDIV'].values, label=f'150 kHz')
ax[1].vlines(0, -10, 10, color='black', alpha=0.5)
ax[1].set_ylabel('Normalized signal from Mirnov coil ')
ax[1].legend()

ax[2].plot(np.arange(160*(-0.0335), 160*0.0335, 0.0335), df_30.iloc[1500:1500+160+160]['mcDIV'].values, label=f'30 kHz')
ax[2].vlines(0, -10, 10, color='black', alpha=0.5)
ax[2].set_xlabel('Time [ms]')
ax[2].legend()

# %% [markdown]
# ### Same graph, but on same time scale for each frequency

# %%
df_30 = pd.read_csv(f'/compass/Shared/Users/bogdanov/vyzkumny_ukol/data/mirnov_coil_signal_30kHz/shot_18463.csv')
df_300= pd.read_csv(f'/compass/Shared/Users/bogdanov/vyzkumny_ukol/data/mirnov_coil_signal_300kHz/shot_18463.csv')
df_150 = pd.read_csv(f'/compass/Shared/Users/bogdanov/vyzkumny_ukol/data/mirnov_coil_signal_150kHz/shot_18463.csv')


fig, ax = plt.subplots(3, 1, figsize=(10, 8))
ax[0].set_title(f'ELM shot 18463, time 1128.38 ms')
ax[0].plot(np.arange(160*(-0.0035), 160*0.0035, 0.0035), df_300.iloc[47687-2-160:47687-2+160]['mcDIV'].values, label=f'300 kHz')
ax[0].vlines(0, -45, 45, color='black', alpha=0.5)
ax[0].vlines(-0.054, -45, 45, color='r', label='start ELM')
ax[0].vlines(0.349, -45, 45, color='r', label='end ELM')
ax[0].legend()

ax[1].plot(np.arange(80*(-0.0065), 80*0.0065, 0.0065), df_150.iloc[25678-2-80:25678-2+80]['mcDIV'].values, label=f'150 kHz')
ax[1].vlines(0, -45, 45, color='black', alpha=0.5)
ax[1].vlines(-0.054, -45, 45, color='r')
ax[1].vlines(0.349, -45, 45, color='r')
ax[1].set_ylabel('Normalized signal from Mirnov coil ')
ax[1].legend()

ax[2].plot(np.arange(16*(-0.0335), 16*0.0335, 0.0335), df_30.iloc[4983-2-16:4983-2+16]['mcDIV'].values, label=f'30 kHz')
ax[2].vlines(0, -45, 45, color='black', alpha=0.5)
ax[2].vlines(-0.054, -45, 45, color='r')
ax[2].vlines(0.349, -45, 45, color='r')
ax[2].set_xlabel('Time [ms]')
ax[2].legend()

# %% [markdown]
# # Here are confidennce vs time graphs

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import alt_models as am

# %%
sampling_freq = 150
path = os.getcwd()

# %%
shot = 16773
# %matplotlib widget


preds_csv = pd.read_csv(f'/compass/Shared/Users/bogdanov/recovery/runs/24-03-21, 15-49-40 Simple1DCNN testing extrasensory model, 4 mirnov_coils, 320 window, 150 sampling_freq/predictions_on_test_dset_df.csv')
pred_for_shot = preds_csv[preds_csv['shot']==shot]
h_alpha = pd.read_csv(f'{path}/data/h_alpha_signal_{sampling_freq}kHz/shot_{shot}.csv')
signals_df = pd.read_csv(f'{path}/data/mirnov_coil_signal_{sampling_freq}kHz/shot_{shot}.csv')
#norming h_alpha
h_alpha['h_alpha'] = (h_alpha['h_alpha'] - h_alpha['h_alpha'].mean())/h_alpha['h_alpha'].std()


# these are matplotlib.patch.Patch properties
df_merged = pd.merge_asof(pred_for_shot, h_alpha, on='time', tolerance=1/sampling_freq, direction='nearest')


conf_time_fig, conf_time_ax = plt.subplots(5,1, sharex=True, 
                                           figsize=(8,8),gridspec_kw={'height_ratios': [1.5, 1,1,1,1]})
conf_time_ax[0].plot(df_merged['time'],df_merged['H_logit'], label='H-mode Confidence')
conf_time_ax[0].plot(df_merged['time'],-df_merged['ELM_logit'], label='ELM Confidence')
conf_time_ax[0].scatter(df_merged[df_merged['label']==1]['time'], 
                  len(df_merged[df_merged['label']==1])*[1], 
                  s=5, alpha=1, label='H-mode Truth', color='maroon')
        
conf_time_ax[0].scatter(df_merged[df_merged['label']==2]['time'], 
                  len(df_merged[df_merged['label']==2])*[-1], 
                  s=5, alpha=1, label='ELM Truth', color='royalblue')
conf_time_ax[0].set_title(f'Confidence and signals for shot {shot}')

conf_time_ax[0].set_ylabel('Confidence')
conf_time_ax[0].legend(loc='upper left', bbox_to_anchor=(0,1.6))

conf_time_ax[1].plot(df_merged['time'],signals_df['mcHFS'].values, label='mcHFS')
conf_time_ax[2].plot(df_merged['time'],signals_df['mcLFS'].values, label='mcLFS')
conf_time_ax[3].plot(df_merged['time'],signals_df['mcTOP'].values, label='mcTOP')
conf_time_ax[4].plot(df_merged['time'],signals_df['mcDIV'].values, label='mcDIV')

#h_alpha_ax = conf_time_ax[0].twinx()
#h_alpha_ax.set_ylabel(r'H_$\alpha$ signal normalized')
#h_alpha_ax.set_ylim(-2, 2)
#h_alpha_ax.plot(df_merged['time'],df_merged['h_alpha'].values, label='H_alpha', color='green', alpha=0.5)

for i, signal_label in enumerate(['mcHFS', 'mcLFS', 'mcTOP', 'mcDIV']):
    conf_time_ax[i+1].set_ylabel(signal_label)


conf_time_ax[4].set_xlabel('t [ms]')
# Out:
# Text(0.5, 0, 't [ms]')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.close()

# %% [markdown]
# # Grad CAM

# %%
import torch
from torch.nn import functional as F
import numpy as np
device = torch.device("cuda:0") if torch.cuda.is_available() else torch.device("cpu")
import torch.nn as nn
import torchvision
import confinement_mode_classifier as cmc
import os
path = os.getcwd()
import pandas as pd
import matplotlib.pyplot as plt
ris_option = 'RIS1'
second_img_opt = None
num_workers = 6
batch_size = 32


# Assume model is your pre-trained ResNet model
# Assume input_tensor is your preprocessed image tensor, e.g., (1, 3, H, W)
#Initiate a single camera model
pretrained_model = torchvision.models.resnet18(weights='IMAGENET1K_V1', )
# Parameters of newly constructed modules have requires_grad=True by default
num_ftrs = pretrained_model.fc.in_features
pretrained_model.fc = nn.Linear(num_ftrs, 2) #3 classes: L-mode, H-mode, ELM
pretrained_model = pretrained_model.to(device)

#Which model to test?
model_path = f'{path}/runs/24-03-17, 19-03-59 RIS1Testing augmentation with RIS1_last_fc'

#TEST one camera model
pretrained_model.load_state_dict(torch.load(f'{model_path}/model.pt'))
pretrained_model.eval()
pretrained_model.to(device)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
shot_usage = pd.read_csv(f'{path}/data/shot_usage.csv')
shot_for_ris = shot_usage[shot_usage['used_for_ris1'] & shot_usage['used_for_ris2']]
shot_numbers = shot_for_ris['shot']
shots_for_testing = shot_for_ris[shot_for_ris['used_as'] == 'test']['shot']
shots_for_validation = shot_for_ris[shot_for_ris['used_as'] == 'val']['shot']
shots_for_training = shot_for_ris[shot_for_ris['used_as'] == 'train']['shot']
# #Testing specific shots
# shot_numbers = [17838, 17714, 19223]
# shots_for_testing = shot_numbers
# shots_for_validation = []

shot_df, test_df, val_df, train_df = cmc.load_and_split_dataframes(path, shot_numbers,
                                                                   shots_for_training, 
                                                                   shots_for_testing, 
                                                                   shots_for_validation, use_ELMS=False,
                                                                   ris_option=ris_option)

#Get dataloaders. second_img_opt='RIS1' indicates that two RIS1 models will be ensembled
test_dataloader = cmc.get_dloader(test_df, path=path, batch_size=batch_size,
                                   shuffle=False, balance_data=True, 
                                 second_img_opt=second_img_opt, 
                                   num_workers=num_workers, augmentation=False)a
# Out:
# No such comm: 45a039c11cc843b89bc5a243aa5d6f87

# %%
example_input = next(iter(test_dataloader))['img'][0].to(device).unsqueeze(0)

example_input.size()
# Out:
# torch.Size([1, 3, 500, 640])

# %%
# Global variable to store feature maps



# Hook function to save the feature maps
def get_feature_maps_hook(module, input, output):
    global feature_maps
    feature_maps = output

# 1. Register hook for the gradients of the target layer
def save_grad_hook(module, input, output):
    global feature_grad
    feature_grad = output[0]

target_layer = pretrained_model.layer1[1].conv2
activation_hook = target_layer.register_forward_hook(get_feature_maps_hook)
grad_hook = target_layer.register_full_backward_hook(save_grad_hook)

# 2. Forward pass
output = pretrained_model(example_input.float())
_, target_class = output.max(dim=1)

# 3. Backward pass
pretrained_model.zero_grad()
target = torch.zeros(output.shape, dtype=torch.float).to(device)
target[0][target_class] = 1
output.backward(gradient=target)

# 4. Generate heatmap

weights = torch.mean(feature_grad, [2, 3])[0, :]


cam = torch.zeros((feature_maps.shape[2], feature_maps.shape[3]), dtype=torch.float).to(device)
for i, weight in enumerate(weights):
    cam += weight * feature_maps[0, i, :, :].to(device)  # Adjusted indexing



plt.imshow(cam.cpu().detach().numpy())

# %%
import confinement_mode_classifier as cmc

cmc.imshow(example_input[0])

# %% [markdown]
# ## Soft-labels

# %%
import alt_models as am
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
path = os.getcwd()
shot_usage = pd.read_csv(f'{path}/data/shot_usage.csv')
shot_for_alt = shot_usage[shot_usage['used_for_alt']]
shot_numbers = shot_for_alt['shot']
shots_for_testing = shot_for_alt[shot_for_alt['used_as'] == 'test']['shot']
shots_for_validation = shot_for_alt[shot_for_alt['used_as'] == 'val']['shot']
shots_for_training = shot_for_alt[shot_for_alt['used_as'] == 'train']['shot']
shot_df, test_df, val_df, train_df = am.split_df(path, shot_numbers,shots_for_training, 
                                                 shots_for_testing, shots_for_validation, use_ELMs=True, signal_name='mc', sampling_freq=150, exponential_elm_decay=True)

shot = 18052
# %matplotlib widget

dummy_df = shot_df[shot_df['shot']==18052]

# %%
dummy_df
# Out:
#              time       mcHFS       mcLFS       mcDIV      mcTOP mode   shot  \
# 497751   961.1135   -3.630981  163.186968   -3.067043   5.831595    0  18052
# 497752   961.1200  -12.531853   29.109597   -9.489732  21.554157    0  18052
# 497753   961.1265    0.296999   37.530420  -10.332100   5.771883    0  18052
# 497754   961.1330   -6.244463  127.330380   -5.735637  12.101424    0  18052
# 497755   961.1395   -9.009326   17.072807   -5.623427  16.296806    0  18052
# ...           ...         ...         ...         ...        ...  ...    ...
# 531700  1181.7820   87.942524  -66.874609  369.605003  -1.973624    0  18052
# 531701  1181.7885   98.309848  -59.322259  335.394644  -2.621858    0  18052
# 531702  1181.7950  105.532425  -55.258142  301.884316 -13.613756    0  18052
# 531703  1181.8015  112.731907  -63.768248  277.110252 -10.943924    0  18052
# 531704  1181.8080  123.559653  -50.416096  254.752495  15.469347    0  18052
#
#        soft_label
# 497751  [1, 0, 0]
# ...

# %%
probs_modes = np.stack(dummy_df['soft_label'].to_numpy())

h_alpha = pd.read_csv(f'{path}/data/h_alpha_signal_{300}kHz/shot_{shot}.csv')
signals_df = pd.read_csv(f'{path}/data/mirnov_coil_signal_{300}kHz/shot_{shot}.csv')
#norming h_alpha
h_alpha['h_alpha'] = (h_alpha['h_alpha'] - h_alpha['h_alpha'].mean())/h_alpha['h_alpha'].std()


# these are matplotlib.patch.Patch properties
df_merged = pd.merge_asof(dummy_df, h_alpha, on='time', tolerance=1/300, direction='nearest')


conf_time_fig, conf_time_ax = plt.subplots(2,1, sharex=True, 
                                           figsize=(10,6))
conf_time_ax[0].plot(df_merged['time'],probs_modes[:,1], label='H-mode ground truth')
conf_time_ax[0].plot(df_merged['time'],-probs_modes[:,2], label='ELM ground truth')
conf_time_ax[0].scatter(df_merged[df_merged['mode_x']==1]['time'], 
                  len(df_merged[df_merged['mode_x']==1])*[1], 
                  s=5, alpha=1, label='H-mode Truth', color='maroon')
        
conf_time_ax[0].scatter(df_merged[df_merged['mode_x']==2]['time'], 
                  len(df_merged[df_merged['mode_x']==2])*[-1], 
                  s=5, alpha=1, label='ELM Truth', color='royalblue')
conf_time_ax[0].set_title(f'Soft labels {shot}')
conf_time_ax[0].hlines(0, df_merged['time'].min(), df_merged['time'].max(), color='black', alpha=0.5, linestyle='-')
conf_time_ax[0].hlines(0.5, df_merged['time'].min(), df_merged['time'].max(), color='maroon', alpha=0.5, linestyle='--')
conf_time_ax[0].hlines(-0.5, df_merged['time'].min(), df_merged['time'].max(), color='royalblue', alpha=0.5, linestyle='--')
conf_time_ax[0].set_ylabel('Logit')
conf_time_ax[0].legend(loc='upper left', bbox_to_anchor=(0,1.6))


conf_time_ax[1].set_ylabel(r'H_$\alpha$ signal scaled')
conf_time_ax[1].set_xlabel(r'time [ms]')
conf_time_ax[1].set_ylim(-2, 2)
conf_time_ax[1].plot(df_merged['time'],df_merged['h_alpha'].values, label='H_alpha', color='green', alpha=0.5)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import FancyBboxPatch, ConnectionPatch

# Create a figure and axis
fig, ax = plt.subplots(figsize=(12, 8))

# Define the layers and their output dimensions
layers = [
    {"name": "Input", "output_dim": "[Batch Size, 4, 320]"},
    {"name": "Conv1D (128 filters)", "output_dim": "[Batch Size, 128, 289]"},
    {"name": "ReLU + BatchNorm", "output_dim": "[Batch Size, 128, 289]"},
    {"name": "Conv1D (64 filters)", "output_dim": "[Batch Size, 64, 257]"},
    {"name": "ReLU + BatchNorm", "output_dim": "[Batch Size, 64, 257]"},
    {"name": "AvgPool1D", "output_dim": "[Batch Size, 64, 29]", "branch": True, "branch_pos": "left"},
    {"name": "MaxPool1D", "output_dim": "[Batch Size, 64, 29]", "branch": True, "branch_pos": "right"},
    {"name": "Concatenate", "output_dim": "[Batch Size, 128, 29]"},
    {"name": "Flatten", "output_dim": "[Batch Size, 3712]"},
    {"name": "Fully Connected (256 units)", "output_dim": "[Batch Size, 256]"},
    {"name": "Output (3 classes)", "output_dim": "[Batch Size, 3]"},
]

# Position variables
x_start = 0.4
y_start = 0.8
box_width = 0.4
box_height = 0.08
y_gap = 0.1

# Draw the layers as boxes with output dimensions
for i, layer in enumerate(layers):
    y_pos = y_start - (i-1) * y_gap
    x_pos = x_start

    if layer.get("branch"):
        if layer["branch_pos"] == "left":
            x_pos -= 0.3
        elif layer["branch_pos"] == "right":
            x_pos += 0.3

    box = FancyBboxPatch((x_pos, y_pos), box_width, box_height,
                         boxstyle="round,pad=0.1", edgecolor='black', facecolor='lightblue')
    ax.add_patch(box)
    ax.text(x_pos + box_width / 2, y_pos + box_height / 2, layer["name"],
            fontsize=12, ha="center", va="center")
    ax.text(x_pos + box_width + 0.05, y_pos + box_height / 2, layer["output_dim"],
            fontsize=10, ha="left", va="center")

    if layer.get("branch"):
        if layer["branch_pos"] == "left":
            ax.plot([x_pos + box_width, x_start + box_width / 2], [y_pos + box_height / 2, y_pos - y_gap / 2], 'k-')
        elif layer["branch_pos"] == "right":
            ax.plot([x_pos, x_start + box_width / 2], [y_pos + box_height / 2, y_pos - y_gap / 2], 'k-')

# Draw the merging line for concatenate
ax.plot([x_start - 0.3 + box_width, x_start + 0.3], [y_start - 5 * y_gap, y_start - 5 * y_gap], 'k-')
ax.plot([x_start + box_width / 2, x_start + box_width / 2], [y_start - 4.5 * y_gap, y_start - 5 * y_gap], 'k-')

# Draw connecting lines between pools and concatenate
left_branch_start = y_start - 5 * y_gap + box_height / 2
right_branch_start = y_start - 6 * y_gap + box_height / 2
concatenate_y = y_start - 7 * y_gap + box_height / 2

ax.add_patch(ConnectionPatch((x_start - 0.15 + box_width, left_branch_start),
                             (x_start + box_width / 2, concatenate_y), "data", "data", linestyle='-', color='black'))
ax.add_patch(ConnectionPatch((x_start + 0.15, right_branch_start),
                             (x_start + box_width / 2, concatenate_y), "data", "data", linestyle='-', color='black'))

# Set limits and remove axes
ax.set_xlim(0, 1.3)
ax.set_ylim(0, 1)
ax.axis('off')

# Show the plot
plt.show()
